# %%
import nltk
import json
import pycountry
import re
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

from nltk.corpus import stopwords

# %% [markdown]
# ### Loading the dataset

# %%
def load_tweets():
    path = 'dataset_tweets_WHO.txt'
    tweets = []
    with open(path,"r",encoding='utf-8') as fp:
        for line in fp:
            tweet_ = json.loads(line)
            for key in tweet_.keys():
                tweet = []
                tweet.append(key)
                tweet.append(tweet_[key]['full_text'])
                tweet.append(tweet_[key]['lang'])
                tweets.append(tweet)
    return tweets

# %%
def remove_stopwords(string,language):
    #we build the stopwords set depending on the language of the tweet.
    stop_words = set(stopwords.words(language))         
    return [word for word in string if word not in stop_words]


def stemming(string,language):
    porter_stemmer = PorterStemmer()
    if language in SnowballStemmer.languages:
        snowball_stemmer = SnowballStemmer(language)
        return [snowball_stemmer.stem(word) for word in string]
    else:
        return [porter_stemmer.stem(word) for word in string]

def clean(string,language):
    
    string = string.lower()
    string = string.split() #tokenize
    string = [re.sub("[^a-z0-9#@]","",word) for word in string] #we remove everything except words, numbers # and @.
    string = [word for word in string if word != ''] # we delete the token that are empty.
    
    if len(language) == 2:
            language = pycountry.languages.get(alpha_2=language).name.lower()
    elif len(language) == 3:
            language = pycountry.languages.get(alpha_3=language).name.lower()
            
    string = remove_stopwords(string,language)  #remove stopwords
    string = stemming(string,language)   #stemming

    return string

# %%
tweets = load_tweets()

filtered_tweets = []
for tweet in tweets:
    try:
        filtered_tweets.append([tweet[0],clean(tweet[1],tweet[2]),tweet[2]])
    except:
        pass

# %%
for tweet in filtered_tweets:
    print(tweet)
# Out:
# ['0', ['intern', 'day', 'disast', 'risk', 'reduct', '#openwho', 'launch', 'multiti', 'core', 'curriculum', 'help', 'equip', 'compet', 'need', 'work', 'within', 'public', 'health', 'emerg', 'respons', 'start', 'learn', 'today', 'amp', '#ready4respons', 'httpstcohbffof0xkl', 'httpstcofgzy22rwus'], 'en']
# ['1', ['#covid19', 'shown', 'health', 'emerg', 'disast', 'affect', 'entir', 'communiti', 'especi', 'weak', 'health', 'system', 'vulner', 'popul', 'like', 'migrant', 'indigen', 'peopl', 'live', 'fragil', 'humanitarian', 'condit', 'httpstcojpuqpnu0v1'], 'en']
# ['2', ['intern', 'day', 'disast', 'risk', 'reduct', 'better', 'respond', 'emerg', 'countri', 'must', 'invest', 'health', 'care', 'system', 'achiev', 'gender', 'equiti', 'protect', 'marginalis', 'group', 'ensur', 'readi', 'amp', 'equit', 'access', 'suppli', 'strong', 'amp', 'resili', 'health', 'system', 'httpstco5nalyjiymp'], 'en']
# ['3', ['rt', '@whoafro', 'congratul', 'algeria', '#algeria', '16th', 'countri', '#africa', 'reach', 'mileston', 'fulli', 'vaccin', '10', 'pop'], 'en']
# ['4', ['rt', '@opsoms', 'si', 'est', 'complet', 'vacun', 'an', 'pued', 'contr', 'covid19', 'import', 'si', 'est', 'vacun', 'si', 'todav', 'est', 'esper', 's'], 'es']
# ['5', ['rt', '@whosearo', '#inform', 'come', 'sourc', 'verifi', 'share', '#checkbeforeyoushar', 'httpstcovr'], 'en']
# ['6', ['rt', '@drtedro', 'must', 'appreci', 'role', 'privat', 'sector', 'play', '#covid19', 'respons', 'develop', 'vaccin', 'short'], 'en']
# ['7', ['rt', '@drtedro', 'human', 'fail', 'miser', 'vaccin', 'injustic', 'debat', 'whether', 'intellectu', 'properti', 'right', 'waiv'], 'en']
# ['8', ['rt', '@drtedro', '#covid19', 'major', 'impact', 'peopl', '#mentalhealth', 'thank', '@doctorja', '@whophilippin', 'dedic', 'work'], 'en']
# ['9', ['rt', '@drtedro', 'broad', 'administr', 'booster', 'dose', 'unfair', 'unjust', 'amp', 'immor', 'time', '#healthwork', 'amp', 'risk', 'peopl', 'mani'], 'en']
# ['10', ['rt', '@drtedro', '1951', 'henrietta', 'lack', 'die', '#cervicalcanc', 'age', '31', '8', 'month', 'diagnosi', 'although', 'life'], 'en']
# ['11', ['rt', '@drtedro', 'donat', 'arent', 'enough', 'deliv', '#vaccinequ', 'end', '#covid19', 'pandem', 'need', 'stronger', 'leadership', 'ramp'], 'en']
# ['12', ['rt', '@whoafghanistan', 'nine', 'flight', 'arriv', '#afghanistan', 'total', '186', 'metric', 'tonn', '@who', 'health', 'suppli', 'sinc', 'august', '30'], 'en']
# ['13', ['rt', '@whoafro', 'medic', 'oxygen', 'vital', 'treat', 'critic', 'ill', '#covid19', 'patient', 'suppli', 'challeng', 'across', '#africa', 'new', 'oxygen'], 'en']
# ['14', ['live', '@drtedro', 'end', '#covid19', 'pandem', 'road', 'inclus', 'recoveri', '#vaccinequ', 'httpstcoq9x4v3ixbl'], 'en']
# ['15', ['rt', '@drtedro', 'good', 'meet', '@chikwei', 'soon', 'head', 'work', 'health', 'emerg', 'surveil', 'incl', '@who', 'hub', 'pandem', 'amp', 'ep'], 'en']
# ['16', ['live', 'qampa', 'post#covid19', 'condit', 'dr', '@diazjv', 'joni', 'savolainen', '@longcovidso', 'repres', '#askwho', 'httpstcohs7haklgwr'], 'en']
# ['17', ['#askwho', 'live', 'qampa', 'dr', '@diazjv', 'clinic', 'care', 'lead', 'amp', 'joni', 'savolainen', '@longcovidso', 'repres', 'today', '5pm', 'cest', 'twitter', 'facebook', 'linkedin', 'amp', 'youtub', 'tune', 'amp', 'ask', 'question', 'post#covid19', 'condit', 'httpstcoqgxd6j6sjk'], 'en']
# ['18', ['take', '#climateact', 'call', 'countri', 'must', 'set', 'ambiti', 'commit', 'sustain', 'healthi', 'amp', 'green', 'recoveri', 'pandem', 'whos', 'call', 'assur', 'sustain', 'recoveri', '#covid19', 'httpstcowxmdmgpswv', 'httpstcoasbosi6lmz'], 'en']
# ['19', ['ahead', '#cop26', '300', 'organ', 'repres', 'least', '45', 'million', '#healthwork', 'worldwid', 'call', 'world', 'leader', 'step', '#climateact', 'limit', 'global', 'warm', '15c', 'put', 'health', 'center', 'plan', 'read', 'httpstcowxmdmgpswv', 'httpstcoiax40auf8d'], 'en']
# ['20', ['peopl', 'around', 'breath', 'unhealthi', 'level', '#airpollut', 'larg', 'result', 'burn', 'fossil', 'fuel', 'drive', '#climatechang', '#climateact', 'could', 'reduc', 'total', 'number', 'global', 'death', 'air', 'pollut', '80', 'httpstco43l5mmawoq', 'httpstcoqz5kerdi1x'], 'en']
# ['21', ['rt', '@drtedro', 'year', '#dayofthegirl', 'theme', 'digit', 'generat', 'generat', 'digit', 'onlin', 'resourc', 'enabl', 'girl'], 'en']
# ['22', ['join', 'us', 'celebr', 'worldchang', 'legaci', 'henrietta', 'lack', 'whose', '#helacel', 'enabl', 'medic', 'breakthrough', 'hpv', 'polio', 'vaccin', '#covid19', 'research', 'join', 'us', 'amp', '@lacksfamili', 'honour', 'legaci', 'amp', 'call', '#healthequ', 'around', 'world', 'httpstcozrwkkgkhxa', 'httpstcosafvwl3kmf'], 'en']
# ['23', ['extrem', 'weather', 'event', 'heat', 'wave', 'flood', 'storm', 'kill', 'thousand', 'amp', 'disrupt', 'million', 'live', 'threaten', 'healthcar', 'system', 'amp', 'facil', 'need', '#climateact', 'protect', 'health', 'httpstcowxmdmgpswv', 'httpstco9itfmjean'], 'en']
# ['24', ['rt', '@drtedro', 'thank', 'partner', 'join', 'forum', 'especi', 'global', 'goodwil', 'ambassador', '#mentalhealth', '@momgerm', 'co'], 'en']
# ['25', ['rt', '@drtedro', 'also', 'need', 'advanc', 'effort', 'support', 'countri', 'integr', '#mentalhealth', 'support', 'school', 'communiti'], 'en']
# ['26', ['rt', '@drtedro', 'today', '@who', 'conven', 'annual', '#mentalhealth', 'forum', 'ask', 'particip', 'focus', 'recogn', '#covid19', 'pandem'], 'en']
# ['27', ['whos', '10', 'call', '#climateact', '6', 'reimagin', 'urban', 'environmentstransportmobl', '7', 'protect', 'amp', 'restor', 'natur', '8', 'promot', 'healthi', 'sustain', 'amp', 'resili', '#foodsystem', '9', 'financ', 'healthierfairergreen', 'futur', 'listen', 'health', 'communiti', 'httpstcowxmdmgpswv', 'httpstcozga2jsucnl'], 'en']
# ['28', ['whos', '10', 'call', '#climateact', '1', 'commit', 'healthi', 'recoveri', '2', 'place', 'health', 'climat', 'talk', '3', 'har', 'health', 'benefit', 'climat', 'action', '4', 'build', 'health', 'resili', 'climat', 'risk', '5', 'creat', 'greener', 'amp', 'healthier', 'energi', 'system', 'httpstcowxmdmgpswv', 'httpstcocomzebqgxz'], 'en']
# ['29', ['#climatecrisi', 'harm', 'health', '#climatecrisi', 'harm', 'health', '#climatecrisi', 'harm', 'health', 'limit', 'global', 'warm', '15c', 'isnt', 'right', 'thing', 'also', 'share', 'respons', 'health', '#cop26', 'special', 'report', 'explain', 'httpstcowxmdmgpswv', 'httpstcor8nfs1oi37'], 'en']
# ['30', ['digit', 'media', 'contribut', 'educ', 'counsel', 'care', 'relat', 'sexual', 'sexual', 'ident', 'sexual', 'relationship', 'among', 'adolesc', 'girl', 'learn', 'whos', 'work', 'outofschool', 'comprehens', 'sexual', 'educ', 'httpstco79fbedzfox', '#dayofthegirl', 'httpstcoslbvrsdwfc'], 'en']
# ['31', ['#covid19', 'pandem', 'onlin', 'ictfacilit', 'violenc', 'women', 'girl', 'continu', 'heighten', '#dayofthegirl', 'let', 'commit', 'make', 'social', 'media', 'onlin', 'space', 'safer', 'girl', 'httpstcosywubz07oz'], 'en']
# ['32', ['near', '1', '4', 'adolesc', 'girl', 'relationship', 'experi', 'physic', 'andor', 'sexual', 'violenc', 'intim', 'partner', 'use', 'resourc', 'address', 'violenc', 'women', 'amp', 'girl', 'context', '#covid19', 'httpstco79fbedzfox', '#dayofthegirl', 'httpstcowujesthltw'], 'en']
# ['33', ['#dayofthegirl', 'call', 'world', 'everi', 'girl', 'access', 'afford', 'qualiti', 'health', 'servic', 'girl', 'treat', 'respect', 'equal', '#healthforal', 'httpstcoyh3eq6dwg6'], 'en']
# ['34', ['progress', 'made', 'last', 'two', 'decad', 'ensur', 'everi', 'girl', 'abl', 'grow', 'develop', 'good', 'health', 'much', 'still', '#dayofthegirl', 'everi', 'day', 'let', 'make', 'health', 'wellb', 'girl', 'prioriti', 'httpstco7ywm2nqbrr'], 'en']
# ['35', ['today', 'intern', '#dayofthegirl', 'girl', 'abl', 'make', 'decis', 'stay', 'school', 'prevent', 'pregnanc', 'access', 'health', 'servic', 'equal', 'transform', 'futur', 'power', 'chang', 'httpstco79fbedzfox', 'httpstcoqcdybtsty7'], 'en']
# ['36', ['live', '@drtedro', '@whoemro', 'region', 'committe', '#emrc68', 'httpstcozviekk33yw'], 'en']
# ['37', ['amp', 'peopl', 'move', 'citi', 'risk', 'massoutbreak', 'increas', 'amp', '#yellowfev', 'except', 'find', 'urban', 'increas', 'proxim', 'peopl', 'amp', 'sprawl', 'expans', 'citi', 'natur', 'impact', 'risk', 'pandem', 'httpstcoocnf6vdrqr', 'httpstcolh7aukmj1p'], 'en']
# ['38', ['rt', '@who', 'close', '1', 'billion', 'peopl', '#mentalhealth', 'disord', 'despit', 'magnitud', 'mental', 'ill', 'health', 'relat', 'peopl', 'aroun'], 'en']
# ['39', ['rt', '@whophilippin', 'meet', 'ario', 'tiger', 'new', 'buddi', 'help', 'stay', 'hope', 'well', 'even', 'month', 'live'], 'en']
# ['40', ['rt', '@whonamibia', 'today', '#worldmentalhealthday', '#covid19', 'pandem', 'signific', 'disrupt', 'mental', 'health', 'care', 'servic', 'tim'], 'en']
# ['41', ['rt', '@whosyria', 'sinc', 'onset', '#covid19', '@who', 'partner', 'reach', '333', '000', 'children', 'caregiv', 'elder', 'mental', 'health', 'ca'], 'en']
# ['42', ['rt', '@whosyria', 'part', 'therapeut', 'intervent', 'mental', 'health', 'condit', '2021', '@who', 'deliv', '323000', 'treatment', 'cours'], 'en']
# ['43', ['rt', '@whoeurop', '#worldmentalhealthday', 'ask', 'make', '#mentalhealth', 'care', 'realiti', 'idea', 'adv'], 'en']
# ['44', ['rt', '@whosearo', 'sometim', 'news', 'may', 'get', 'much', '#mentalhealth', 'okay', 'switch', 'time', '#worldmentalhealthday', 'https'], 'en']
# ['46', ['rt', '@whosearo', 'import', 'stay', 'touch', 'love', 'one', 'difficult', 'time', '#mentalhealth', '#worldmentalhealth'], 'en']
# ['47', ['rt', '@whosearo', 'spend', 'much', 'time', 'laptop', 'mobil', 'phone', 'pleas', 'dont', 'take', 'care', '#mentalhealth', '#worldmentalhea'], 'en']
# ['48', ['rt', '@whoafro', 'least', 'one', 'seven', 'children', 'subsaharan', '#africa', 'experi', 'signific', 'psycholog', 'hardship', 'despit', 'high', 'burd'], 'en']
# ['49', ['rt', '@onu', 'depresin', 'pued', 'suced', 'cualqu', 'sign', 'debil', 'enfermed', 'tratamient', '#dadel'], 'es']
# ['50', ['rt', '@whowpro', 'patient', 'differ', 'grandmoth', 'grandfath', 'loyal', 'oath', 'health', 'worker', 'like', 'dr', 'gantsengel', 'pur'], 'en']
# ['51', ['rt', '@whomald', 'pregnant', 'amp', 'babi', 'major', 'life', 'event', 'caus', 'worri', 'tired', 'amp', 'sad', 'wonder', 'pre'], 'en']
# ['52', ['rt', '@whomalawi', 'live', 'care', 'someon', 'mental', 'health', 'condit', 'difficult', 'support', 'valuabl'], 'en']
# ['53', ['rt', '@whotimor', 'think', '#depress', 'rememb'], 'en']
# ['54', ['rt', '@whotimor', '#worldmentalhealthday', 'dyk', '#depress', 'lead', 'caus', 'disabl', 'worldwid', 'major', 'contributor', 'ov'], 'en']
# ['55', ['rt', '@omsafr', 'dpression', 'troubl', 'mental', 'plus', 'rpandu', 'afriqu', 'pourt', '85', 'person', 'souffrent', 'nont', 'ac'], 'fr']
# ['56', ['rt', '@pahowho', 'mani', 'barrier', 'afford', 'access', 'prevent', 'peopl', 'access', 'mental', 'health', 'care', 'ne'], 'en']
# ['57', ['rt', '@whowpro', 'know', 'someon', 'consid', 'suicid', 'way', 'help', 'httpstco0nt8uslcy1', '#preventsuicid'], 'en']
# ['58', ['rt', '@whomald', 'life', 'chang', 'come', '#age', 'caus', 'depress', 'think', 'might', 'risk', 'inform'], 'en']
# ['59', ['rt', '@opsomsbolivi', 'conoc', 'algui', 'est', 'pas', 'depresin', 'compart', 'mensaj', 'pod', 'ayud', '#diamundialdelasaludm'], 'es']
# ['60', ['rt', '@opsomsmex', 'pandemi', '#covid19', 'sid', 'especial', 'dur', 'reconoc', 'experient', 'invit'], 'es']
# ['61', ['rt', '@whophilippin', 'vaccin', 'cant', 'stop', '#covid19', 'alon', 'help', 'protect', 'love', 'one', 'covid'], 'en']
# ['62', ['rt', '@who', 'today', '#worldmentalhealthday', '#covid19', 'major', 'impact', 'peopl', '#mentalhealth', 'health', 'worker', 'student', 'peopl', 'livin'], 'en']
# ['63', ['rt', '@alissonbeck', 'support', '@who', '@fifacom', '#worldmentalhealthday', 'let', 'support', 'feel', 'depress', '#reachout'], 'en']
# ['64', ['rt', '@alissonbeck', 'support', 'especi', 'tough', 'time', 'never', 'walk', 'alon', 'stronger', 'togeth', '#reachout', '#'], 'en']
# ['65', ['tolus', 'sociabl', 'outgo', '#covid19', 'pandem', 'took', 'away', 'start', 'question', 'point', 'life', 'access', '#mentalhealth', 'care', 'help', 'overcom', 'clinic', '#depress', 'watch', 'stori', '#worldmentalhealthday', 'httpstcovnttwrg20o'], 'en']
# ['66', ['arsha', 'first', 'famili', 'infect', '#covid19', 'quarantin', 'led', 'anxieti', 'share', 'famili', 'support', 'essenti', 'seek', 'profession', 'help', '#worldmentalhealthday', 'httpstcoid6j60sy9x'], 'en']
# ['67', ['jordan', 'lost', 'job', '#covid19', 'pandem', 'one', 'lucki', 'found', '#mentalhealth', 'support', 'get', 'difficult', 'time', 'need', 'mental', 'health', 'care', 'everyon', 'everywher', '#worldmentalhealthday', 'httpstco1jocbbstwm'], 'en']
# ['68', ['rt', '@drtedro', 'dear', 'teresa', 'enk', 'thank', 'messag', 'support', '@who', '#worldmentalhealthday', 'remain', 'midst'], 'en']
# ['69', ['rt', '@drtedro', 'thank', '@flotus', 'support', '#worldmentalhealthday', 'campaign', 'encourag', 'peopl', 'seek', 'help', 'ok'], 'en']
# ['70', ['common', '#mentalhealth', 'condit', 'depress', 'anxieti', 'treat', 'talk', 'therapi', 'medic', 'combin', 'laxmi', 'share', 'counsellor', 'support', 'help', 'overcom', 'feel', '#depress', '#worldmentalhealthday', 'httpstcos4ca8vjat0'], 'en']
# ['71', ['serious', 'gap', '#mentalhealth', 'care', 'result', 'chronic', 'underinvest', '#worldmentalhealthday', 'call', 'invest', 'mental', 'health', 'care', 'sebastian', 'say', 'access', 'mental', 'health', 'care', 'essenti', 'cope', '#covid19', 'pandem', 'httpstcodxhvpsdavb'], 'en']
# ['72', ['close', '1', 'billion', 'peopl', '#mentalhealth', 'disord', 'despit', 'magnitud', 'mental', 'ill', 'health', 'relat', 'peopl', 'around', 'access', 'qualiti', 'mental', 'health', 'servic', 'hear', 'helen', 'speak', 'truth', 'access', 'mental', 'health', 'care', 'essenti', 'httpstcod7zlml2b2d'], 'en']
# ['73', ['#worldmentalhealthday', '#letstalk', 'httpstcoahzerh0nqb'], 'en']
# ['74', ['suicid', 'thought', 'talk', 'someon', 'trust', 'talk', 'health', 'worker', 'counsellor', 'social', 'worker', 'join', 'support', 'group', 'think', 'your', 'immedi', 'danger', 'harm', 'contact', 'emerg', 'servic', 'crisi', 'line', '#worldmentalhealthday', 'httpstcosuwkt1pkam'], 'en']
# ['75', ['rt', '@drtedro', 'thank', '@rgrosjean', 'join', '@whos', '#worldmentalhealthday', 'campaign', 'encourag', 'everyon', 'open', 'seek', 'help'], 'en']
# ['76', ['rt', '@drtedro', 'thank', 'leadership', 'encourag', 'peopl', '#malaysia', 'talk', '#mentalhealth', 'health', 'minist', '@khair'], 'en']
# ['77', ['your', 'suicid', 'thought', 'need', 'know', 'think', '#suicid', 'selfharm', 'sign', 'sever', 'emot', 'distress', 'get', 'better', '#worldmentalhealthday', '#letstalk', 'httpstcouhf51jc3iq'], 'en']
# ['78', ['your', 'suicid', 'thought', 'need', 'know', 'mani', 'peopl', 'gone', 'your', 'experienc', 'found', 'help', 'ok', 'talk', '#suicid', '#worldmentalhealthday', '#letstalk', 'httpstcodof88nwztt'], 'en']
# ['79', ['experienc', 'follow', 'pain', 'seem', 'overwhelm', 'amp', 'unbear', 'feel', 'worthless', 'hopeless', 'loneli', 'constant', 'negat', 'thought', 'difficulti', 'imagin', 'way', 'deal', 'problem', '#suicid', 'alon', 'httpstcoq6fashsgf0'], 'en']
# ['80', ['feel', 'like', 'life', 'worth', 'live', '#letstalk', 'ask', 'help', '#worldmentalhealthday', 'httpstcoyxloa7jgd1'], 'en']
# ['81', ['rt', '@drtedro', '#worldmentalhealthday', '@who', 'also', 'provid', 'new', 'easytoread', 'materi', 'take', 'care', '#mentalhealth'], 'en']
# ['82', ['rt', '@drtedro', 'year', '#worldmentalhealthday', 'campaign', '@who', 'showcas', 'effort', 'countri', 'encourag', 'everyon', 'highlight'], 'en']
# ['83', ['rt', '@drtedro', 'today', '#worldmentalhealthday', '#covid19', 'pandem', 'major', 'impact', 'peopl', 'mental', 'health', 'signific'], 'en']
# ['84', ['someon', 'r', '#', '#worldmentalhealthday', '#letstalk', 'httpstcowkgsedjvjo'], 'en']
# ['85', ['warn', 'sign', 'someon', 'may', 'think', '#suicid', 'say', 'goodby', 'close', 'famili', 'friend', 'say', 'thing', 'like', 'noon', 'miss', 'im', 'gone', 'give', 'away', 'valu', 'possess', '#worldmentalhealthday', '#letstalk', 'httpstcowk6s5o0gxl'], 'en']
# ['86', ['live', '@twitterspac', '@fahmyhanna', '@ventevogelpeter@refuge', 'talk', '#mentalhealth', 'emerg', 'join', 'us', '#askwho', 'question', '#worldmentalhealthday', 'httpstco8n63jwdkkl'], 'en']
# ['87', ['warn', 'sign', 'someon', 'may', 'think', '#suicid', 'sever', 'mood', 'chang', 'social', 'withdraw', 'express', 'thought', 'plan', 'end', 'life', '#worldmentalhealthday', '#letstalk', 'httpstcohy5qf8hwcm'], 'en']
# ['88', ['think', 'someon', 'may', 'consid', '#suicid', 'rememb', 'mani', 'peopl', 'think', 'suicid', 'point', 'live', 'suicid', 'thought', 'behaviour', 'sign', 'sever', 'emot', 'distress', 'weak', 'possibl', 'get', 'better', '#worldmentalhealthday', 'httpstcot2qcqornm8'], 'en']
# ['89', ['worri', 'someon', 'know', 'may', 'consid', '#suicid', '#letstalk', 'know', 'show', 'care', '#worldmentalhealthday', 'httpstcow4vvecv3ji'], 'en']
# ['90', ['#', '#worldmentalhealthday', '#letstalk', 'httpstcoko4ykmgxgl'], 'en']
# ['91', ['set', 'remind', 'join', '@twitterspac', 'chat', '#mentalhealth', 'emerg', 'later', 'today', '1600h', 'cest', '@fahmyhanna', '@ventevogelpeter@refuge', '#worldmentalhealthday', '#askwho', 'httpstco8n63jwdkkl'], 'en']
# ['92', ['your', 'worri', 'someon', 'risk', '#suicid', 'here', 'live', 'remov', 'access', 'mean', 'selfharm', 'theyr', 'immedi', 'danger', 'contact', 'emerg', 'servic', 'dont', 'leav', 'alon', '#worldmentalhealthday', '#letstalk', 'httpstcole71tujgus'], 'en']
# ['93', ['live', '@twitterspac', '@alischafer4', '@doctorja', 'amp', '@debramachando', 'talk', '#mentalhealth', 'care', 'join', 'us', '#askwho', 'question', '#worldmentalhealthday', 'httpstconvs5jv75dp'], 'en']
# ['94', ['rt', '@who', 'set', 'remind', 'join', '@twitterspac', 'chat', '#mentalhealth', 'care', '10', 'octob', '1200', 'pm', 'cest', '@alischafer4', '@d'], 'en']
# ['95', ['your', 'worri', 'someon', 'risk', '#suicid', 'here', 'talk', 'theyr', 'feel', 'encourag', 'seek', 'profession', 'help', 'check', 'regular', '#worldmentalhealthday', '#letstalk', 'httpstcoamjzkzvfkx'], 'en']
# ['96', ['may', 'risk', '#sucid', 'someon', 'whos', 'tri', 'take', 'life', 'peopl', 'depressionemot', 'distress', 'social', 'isol', 'live', 'chronic', 'painil', 'someon', 'alcohol', 'drug', 'problem', 'violenc', 'abus', 'survivor', '#worldmentalhealthday', 'httpstcolcnvb5dzfw'], 'en']
# ['97', ['#worldmentalhealthday', 'dyk', '1', '100', 'death', '#suicid', 'everi', 'suicid', 'mani', 'peopl', 'attempt', 'suicid', 'prior', 'suicid', 'attempt', 'import', 'risk', 'factor', '#letstalk', 'httpstcocugmvd8ohu'], 'en']
# ['98', ['someon', 'know', '#depress', 'rememb', '#worldmentalhealthday', '#letstalk', 'httpstco6cm7ffxvgz'], 'en']
# ['99', ['someon', 'know', '#depress', 'help', 'encourag', 'regular', 'eat', 'sleep', 'exercis', 'encourag', 'focus', 'posit', 'rather', 'negat', 'patient', 'recoveri', 'take', 'time', '#worldmentalhealthday', '#letstalk', 'httpstcou92octvt94'], 'en']
# ['100', ['someon', 'know', '#depress', 'help', 'talk', 'offer', 'support', 'encourag', 'seek', 'profession', 'help', 'help', 'everyday', 'activ', '#worldmentalhealthday', '#letstalk', 'httpstcojb6vab19jh'], 'en']
# ['101', ['think', 'someon', 'know', 'may', '#depress', 'follow', 'thread', 'tip', 'show', 'care', 'offer', 'support', '#worldmentalhealthday', '#letstalk', 'httpstcoxyoyjaunwk'], 'en']
# ['102', ['#depress', 'rememb', 'right', 'support', 'get', 'better', '#worldmentalhealthday', '#letstalk', 'httpstco7gilcg9mq4'], 'en']
# ['103', ['#depress', 'thing', 'help', 'stay', 'connect', 'friend', 'famili', 'stick', 'regular', 'eat', 'sleep', 'habit', 'tri', 'focus', 'posit', '#worldmentalhealthday', '#letstalk', 'httpstcomgcc0q5wzr'], 'en']
# ['104', ['#depress', 'talk', 'someon', 'trust', 'feel', 'seek', 'profession', 'help', 'tri', 'keep', 'activ', 'normal', 'enjoy', '#worldmentalhealthday', '#letstalk', 'httpstcog4qesm37i'], 'en']
# ['105', ['#worldmentalhealthday', 'dyk', '#depress', 'lead', 'caus', 'disabl', 'worldwid', 'major', 'contributor', 'overal', 'global', 'burden', 'diseas', 'depress', 'happen', 'anyon', '#letstalk', 'httpstcoxz9agaxji2'], 'en']
# ['106', ['think', '#depress', 'rememb', '#worldmentalhealthday', '#letstalk', 'httpstcoaveoar0y3'], 'en']
# ['107', ['also', 'symptom', '#depress', 'loss', 'energi', 'chang', 'appetit', 'sleep', 'less', 'anxieti', 'difficulti', 'concentr', 'thought', 'selfharm', 'suicid', '#worldmentalhealthday', '#letstalk', 'httpstcorsq860ssfu'], 'en']
# ['108', ['sign', 'may', '#depress', 'persist', 'sad', 'loss', 'interest', 'activ', 'usual', 'enjoy', 'difficulti', 'carri', 'everyday', 'activ', '#worldmentalhealthday', '#letstalk', 'httpstcou145pzffp'], 'en']
# ['109', ['here', 'know', '#depress', 'happen', 'anyon', 'ill', 'sign', 'weak', 'treat', '#worldmentalhealthday', '#letstalk', 'httpstcolvqp6hgz1f'], 'en']
# ['110', ['think', 'may', '#depress', '#letstalk', 'follow', 'thread', 'symptom', 'depress', 'seek', 'help', '#worldmentalhealthday', 'httpstcomaqhbmytej'], 'en']
# ['111', ['today', '#worldmentalhealthday', '#covid19', 'major', 'impact', 'peopl', '#mentalhealth', 'health', 'worker', 'student', 'peopl', 'live', 'alon', 'amp', 'preexist', 'condit', 'particular', 'affect', '#letstalk', 'today', 'care', 'amp', 'support', '#askwho', 'httpstcovrmni26ekd'], 'en']
# ['112', ['world', 'hospic', 'palliat', 'care', 'day', 'train', 'amp', 'support', '#healthwork', '#palliativecar', 'need', 'scale', 'access', 'qualiti', 'servic', 'palliat', 'care', 'improv', 'live', 'httpstcomebmzestql', 'httpstcolakbxrorhx'], 'en']
# ['113', ['#covid19', 'highlight', 'need', '#palliativecar', 'reliev', 'suffer', 'end', 'life', 'physic', 'suffer', 'caus', 'breathless', 'mental', 'pain', 'result', 'separ', 'love', 'one', 'palliat', 'care', 'improv', 'live', 'httpstcomebmzestql', 'httpstcop4iwirktc4'], 'en']
# ['114', ['qualiti', '#palliativecar', 'bring', 'comfort', 'patient', 'amp', 'famili', 'end', 'life', 'also', 'help', 'achiev', 'univers', 'health', 'coverag', 'uhc', 'provid', 'practic', 'resourc', 'support', 'improv', 'polici', 'strategi', 'amp', 'practic', 'countri', 'httpstcolf4gey1ctr', 'httpstcoqrbbrikbvg'], 'en']
# ['115', ['measur', 'develop', '#palliativecar', 'help', 'countri', 'understand', 'key', 'gap', 'advoc', 'concert', 'action', 'identifi', 'resourc', 'need', 'learn', 'best', 'practic', 'report', 'palliat', 'care', 'explain', 'httpstcotqvd47ng26', 'httpstcohfwuwdmubm'], 'en']
# ['116', ['today', 'world', 'hospic', 'palliat', 'care', 'day', '1', 'peopl', 'need', '#palliativecar', 'receiv', 'let', 'leav', 'one', 'behind', 'make', 'palliat', 'care', 'access', 'amp', 'afford', 'here', 'howhttpstcomebmzestql', 'httpstcodiiwscoilu'], 'en']
# ['117', ['set', 'remind', 'join', '@twitterspac', 'chat', '#mentalhealth', 'care', '10', 'octob', '1200', 'pm', 'cest', '@alischafer4', '@doctorja', 'amp', '@debramachando', '#worldmentalhealthday', 'httpstconvs5jv75dp'], 'en']
# ['118', ['team', '#palliativecar', 'includ', 'doctor', 'nurs', 'support', 'worker', 'pharmacist', 'social', 'worker', 'physiotherapist', 'volunt', 'work', 'togeth', 'support', 'patient', 'amp', 'famili', 'deal', 'lifethreaten', 'ill', 'amp', 'suffer', 'httpstco5fmfjudyyr', 'httpstcowmdumivzx5'], 'en']
# ['119', ['live', '@twitterspac', '@flmandra', '@saraheklin', 'amp', '@tesskunik', 'talk', '#suicideprevent', 'join', 'us', '#askwho', 'question', '#worldmentalhealthday', 'httpstcou71nn3o1hx'], 'en']
# ['120', ['#palliativecar', 'everyon', 'babi', 'children', 'serious', 'ill', 'also', 'benefit', 'palliat', 'care', 'care', 'aim', 'reliev', 'suffer', 'whether', 'caus', 'cancer', 'chronic', 'pain', 'neurolog', 'disord', 'httpstcofyvjnf25bg', 'httpstcofgkjufeqz5'], 'en']
# ['121', ['rt', '@who', 'set', 'remind', 'join', '@twitterspac', 'chat', '#suicideprevent', 'later', 'today', '1600h', 'cest', 'alexandra', 'fleischmannwho', '@'], 'en']
# ['122', ['#palliativecar', 'benefit', 'everyon', 'patient', 'treatment', 'serious', 'ill', 'patient', 'receiv', 'radiat', 'amp', 'chemotherapi', 'cancer', 'patient', 'treat', '#dementia', 'patient', 'receiv', 'treatment', 'drugresist', 'tuberculosi', 'httpstcofyvjnf25bg', 'httpstcolcwgwpkisw'], 'en']
# ['123', ['#palliativecar', 'end', 'life', 'consid', 'earli', 'help', 'reliev', 'troubl', 'symptom', 'pain', 'breathless', 'vomit', 'palliat', 'care', 'benefit', 'everyon', 'httpstco5fmfjudyyr', 'httpstcohfwhw4ckax'], 'en']
# ['124', ['set', 'remind', 'join', '@twitterspac', 'chat', '#suicideprevent', 'later', 'today', '1600h', 'cest', 'alexandra', 'fleischmannwho', '@saraheklin', 'amp', '@tesskunik', '#worldmentalhealthday', 'httpstcou71nn3o1hx'], 'en']
# ['125', ['rt', '@whoafro', 'yesterday', '#drc', 'announc', 'new', '#ebola', 'case', 'detect', 'north', 'kivu', 'provinc', 'previous', 'outbreak', 'declar'], 'en']
# ['126', ['#palliativecar', 'help', 'reliev', 'suffer', 'improv', 'qualiti', 'life', 'patient', 'famili', 'deal', 'serious', 'ill', 'practic', 'help', 'medicin', 'spiritu', 'emot', 'support', 'info', 'httpstco5fmfjudyyr', 'httpstcofpggdvipn0'], 'en']
# ['127', ['live', '@twitterspac', '@chiaraservili', '@zeinabhijazi', '@tolusefr', 'talk', '#mentalhealth', 'young', 'peopl', 'join', 'us', '#askwho', 'question', '#worldmentalhealthday', 'httpstcoqbpyqqey1'], 'en']
# ['128', ['rt', '@drtedro', '@who', 'work', 'govern', '#drc', 'investig', 'case', '#ebola', 'north', 'kivu', 'httpstcouhivqdtpi'], 'en']
# ['129', ['rt', '@drtedro', '#covid19', 'huge', 'impact', 'peopl', '#mentalhealth', '@whos', 'campaign', '#worldmentalhealthday', 'encourag', 'everyon', 'ta'], 'en']
# ['130', ['life', 'threaten', 'serious', 'ill', 'heart', 'failur', 'cancer', 'chronic', 'lung', 'diseas', '#palliativecar', 'offer', 'comfort', 'amp', 'solut', 'improv', 'physic', 'mental', 'wellb', 'patient', 'amp', 'love', 'one', 'info', 'httpstcofyvjnf25bg', 'httpstcov4lvqmac9'], 'en']
# ['131', ['rt', '@drtedro', 'pleas', 'sign', 'memorandum', 'understand', 'sister', '@maimunahsharif', 'strengthen', 'even', 'long', 'stand'], 'en']
# ['132', ['#covid19', 'becom', 'endem', 'dr', '@mvankerkhov', 'explain', 'httpstcoymq7rk33hi'], 'en']
# ['133', ['rt', '@who', 'set', 'remind', 'yet', 'dont', 'miss', '@twitterspac', 'chat', '#mentalhealth', 'amp', 'young', 'peopl', 'chiara', 'servili', 'child'], 'en']
# ['134', ['today', 'world', 'hospic', 'palliat', 'care', 'day', 'dyk', '55', 'million', 'peopl', 'around', 'need', '#palliativecar', '12', 'global', 'need', 'met', 'access', 'palliat', 'care', 'servic', 'human', 'right', 'health', 'httpstcomebmzestql', 'httpstcowq3d40dh6d'], 'en']
# ['135', ['rt', '@whoafro', '#drc', 'ministri', 'health', 'announc', 'new', 'case', 'ebola', 'detect', 'north', 'kivu', 'provinc', 'previous'], 'en']
# ['136', ['central', 'mental', 'hospit', 'amp', 'institut', 'inpati', 'care', 'still', 'receiv', 'fund', 'servic', 'provid', 'general', 'hospit', 'amp', 'primari', 'healthcar', 'centr', 'mani', 'countri', 'transfer', 'care', 'communiti', 'need', 'acceler', 'httpstcoj0ukvkwz46', '#mentalhealth', 'httpstcoutn6dn7yo7'], 'en']
# ['137', ['learn', 'first', '#malaria', 'vaccin', 'receiv', 'vaccin', 'challeng', 'roll', 'malaria', 'vaccin', 'midst', 'pandem', 'dr', '@palonsomalaria', 'explain', '#sciencein5', 'week', 'httpstcordhz2a7e5a'], 'en']
# ['138', ['rt', '@drtedro', 'great', 'profil', 'piec', 'worth', 'read', 'ahead', '#worldmentalhealthday', 'dvora', 'kestel', 'global', 'leader', '#mentalhealth', 'polici'], 'en']
# ['139', ['set', 'remind', 'yet', 'dont', 'miss', '@twitterspac', 'chat', '#mentalhealth', 'amp', 'young', 'peopl', 'chiara', 'servili', 'child', 'amp', 'adolesc', 'mental', 'health', 'expert', '@zeinabhijazi', '@unicef', 'senior', 'mental', 'health', 'technic', 'advisor', '@tolusefr', '#mentalhealth', 'advoc', 'httpstcoewsswexjnp'], 'en']
# ['140', ['progress', 'threat', 'amp', 'resourc', 'lack', 'address', 'new', 'outbreak', 'variant', 'amp', 'global', 'vaccin', 'inequ', 'resourc', 'need', 'fight', '#covid19', 'pandem', 'httpstcoy3fu6evl33', 'httpstcoawuypnyxcu'], 'en']
# ['141', ['cant', 'put', 'fire', 'without', 'fire', 'engin', 'hose', 'water', 'help', 'donor', 'continu', 'fight', '#covid19', 'pandem', 'done', 'far', 'httpstcoy3fu6evl33', 'httpstco7njlspvtj'], 'en']
# ['142', ['support', 'need', 'fight', '#covid19', 'pandem', 'suppress', 'transmiss', 'reduc', 'exposur', 'mortal', 'amp', 'morbid', 'counter', 'misinform', 'protect', 'vulner', 'acceler', 'access', 'tool', 'includ', 'vaccin', 'info', 'httpstcoy3fu6evl33', 'httpstcozf3rtjjyul'], 'en']
# ['143', ['rt', '@opsoms', 'viv', 'atencin', 'salud', 'mental', 'tod', 'person', 'hagmosl', 'realid', 'httpstcosizv51f3qh'], 'es']
# ['144', ['70', 'total', 'govern', 'expenditur', '#mentalhealth', 'alloc', 'mental', 'hospit', 'middleincom', 'countri', 'vs', '35', 'highincom', 'countri', 'httpstcoj0ukvkwz46', 'httpstcojdltswcubb'], 'en']
# ['145', ['rt', '@drtedro', 'colleagu', '@fahmyhanna', '@alisonbruni', 'share', 'key', 'find', '#mentalhealth', 'atlas', 'watch', 'httpstco'], 'en']
# ['146', ['rt', '@drtedro', 'need', '#mentalhealth', 'servic', 'becom', 'even', 'acut', '#covid19', 'pandem', 'must', 'heed', 'challeng'], 'en']
# ['147', ['rt', '@drtedro', '@who', 'issu', '#mentalhealth', 'atlas', 'today', 'highlight', 'global', 'shortfal', 'invest', 'mental', 'health', 'care', 'extr'], 'en']
# ['148', ['1', '6', '#mentalhealth', 'target', 'set', 'global', 'health', 'communiti', '2020', 'achiev', 'progress', 'toward', 'meet', 'other', 'limit', 'httpstcoj0ukvkwz46', 'httpstcoded0qyxuib'], 'en']
# ['149', ['rt', '@whoafghanistan', 'access', '#health', 'afghan', 'fall', 'reach', 'winter', 'approach', '@who', 'health', 'cluster', 'p'], 'en']
# ['150', ['inform', '#mentalhealth', 'pleas', 'visit', 'httpstcon3iaz7wuvf'], 'en']
# ['151', ['live', '#askwho', 'qampa', '#mentalhealth', '@fahmyhanna', 'httpstcocogqyb5tjz'], 'en']
# ['152', ['govern', 'health', 'budget', 'spent', '#mentalhealth', 'scarc', 'chang', 'last', 'year', 'still', 'hover', 'around', '2', 'httpstcoj0ukvkwz46', 'httpstcovmcb98hvf0'], 'en']
# ['153', ['whos', 'strateg', 'prepared', 'respons', 'plan', 'sprp', 'provid', 'implement', 'amp', 'oper', 'support', 'guidanc', 'amp', 'capac', 'build', 'partnership', 'plan', 'amp', 'coordin', 'public', 'health', 'intellig', 'research', 'amp', 'innov', 'monitor', 'amp', 'httpstcog99aikj9kg', 'httpstcojo0i2ultnz'], 'en']
# ['154', ['issu', 'everi', 'three', 'year', '#mentalhealth', 'atlas', 'compil', 'data', 'provid', 'countri', 'around', 'world', 'mental', 'health', 'polici', 'legisl', 'financ', 'human', 'resourc', 'avail', 'util', 'servic', 'amp', 'data', 'collect', 'system', 'httpstcoj0ukvkwz46', 'httpstcouzjxf7lnqw'], 'en']
# ['155', ['@whoemro', '@whosearo', '@whoafro', '@pahowho', '@whowpro', '@whoeurop', '@govuk', 'sometim', 'need', 'take', 'closer', 'look', 'read', '#covid19', 'someth', 'sound', 'unbeliev', 'well', 'might', 'analys', 'fact', '#checkbeforeyoushar', 'httpstcozvjmrng49o', 'httpstco9yixqixszb'], 'en']
# ['156', ['world', 'fail', 'provid', 'peopl', '#mentalhealth', 'servic', 'need', 'new', 'mental', 'health', 'atlas', 'read', 'morehttpstcoj0ukvkwz46', 'httpstco0wkx6jtv2f'], 'en']
# ['157', ['@whoemro', '@whosearo', '@whoafro', '@pahowho', '@whowpro', '@whoeurop', '@govuk', 'awar', '#covid19', 'headlin', 'dont', 'alway', 'tell', 'whole', 'stori', 'alway', 'read', 'end', 'share', 'articl', '#checkbeforeyoushar', 'httpstcozvjmrng49o', 'httpstcovqa0hi03x5'], 'en']
# ['158', ['@whoemro', '@whosearo', '@whoafro', '@pahowho', '@whowpro', '@whoeurop', '@govuk', '#covid19', 'inform', 'come', 'sourc', 'dont', 'know', 'mayb', 'shouldnt', 'go', '#checkbeforeyoushar', 'httpstcozvjmrng49o', 'httpstcouklnvq2shb'], 'en']
# ['159', ['rt', '@drtedro', '#checkbeforeyoushar', 'campaign', 'provid', 'clear', 'step', 'assess', 'whether', '#covid19', 'inform', 'true', 'fals'], 'en']
# ['160', ['inform', 'find', '#socialmedia', 'true', 'use', 'spread', 'mislead', 'news', 'content', 'protect', 'friend', 'fals', 'inform', '#covid19', 'vaccin', '#checkbeforeyoushar', 'httpstcozvjmrng49o', 'httpstco2w9ktzucof'], 'en']
# ['161', ['sinc', 'begin', '#covid19', 'pandem', 'amp', 'partner', 'mount', 'respons', 'unpreced', 'global', 'scale', 'continu', 'provid', 'critic', 'support', 'guidanc', 'countri', 'strateg', 'prepared', 'respons', 'plan', 'sprp', 'httpstcog99aikj9kg', 'httpstcobgrlirgeyd'], 'en']
# ['162', ['rt', '@drtedro', 'inform', 'onlin', 'true', 'help', 'peopl', 'protect', 'love', 'one', 'fals', 'inform', '#covi'], 'en']
# ['163', ['strategi', 'outlin', 'prioriti', 'action', 'need', 'countri', '#covid19', 'vaccin', 'manufactur', 'well', 'civil', 'societi', 'communiti', 'organ', 'privat', 'sector', 'achiev', 'target', 'end', 'pandem', 'httpstcotishopibio'], 'en']
# ['164', ['#vaccinequ', 'requir', 'vaccin', '70', 'global', 'popul', 'suffici', 'vaccin', 'suppli', 'perspect', 'achiev', 'global', '#covid19', 'vaccin', 'target', 'need', 'equit', 'distribut', 'dose', 'around', 'httpstcotishopibio', 'httpstcoib2at5bvca'], 'en']
# ['165', ['rt', '@drtedro', 'speed', 'ensur', 'deliv', '#vaccinequ', 'target', 'mid2022', '@who', 'issu', '#covid19', 'vaccin', 'strategi', 'today'], 'en']
# ['166', ['achiev', 'global', '#covid19', 'vaccin', 'target', '3step', 'vaccin', 'approach', 'everi', 'countri', '1', 'first', 'older', 'adult', 'health', 'worker', 'amp', 'highrisk', 'group', 'age', '2', 'follow', 'full', 'adult', 'age', 'group', '3', 'adolesc', 'httpstcotishopibio', 'httpstcoiegz5p1ygf'], 'en']
# ['167', ['strategi', 'outlin', 'plan', 'achiev', 'target', 'vaccin', '40', 'popul', 'countri', '#covid19', 'end', '2021', '70', 'mid2022', 'httpstcotishopibio', 'httpstcogg4gxqy9xf'], 'en']
# ['168', ['strategi', 'launch', 'today', 'aim', 'help', 'bring', 'end', 'becom', 'twotrack', '#covid19', 'pandem', 'peopl', 'poorer', 'countri', 'continu', 'risk', 'richer', 'countri', 'high', 'vaccin', 'rate', 'enjoy', 'much', 'greater', 'protect', 'httpstcotishopibio', 'httpstcohgiljvvgn'], 'en']
# ['169', ['consult', 'patient', 'clinician', 'stakehold', 'arriv', 'post', '#covid19', 'condit', 'definit', 'peopl', '44', 'countri', '6', 'region', 'particip', 'determin', 'clinic', 'case', 'definit', 'thank', 'contribut', 'process', 'httpstcoqu1b8hapmv'], 'en']
# ['170', ['@drtedro', 'full', 'remark', '@drtedro', 'media', 'brief', '#covid19', '7', 'octob', '2021', 'httpstcoqcaqjeq9hu', 'full', 'remark', '@un', 'secretarygener', '@antonioguterr', 'httpstcoiwwcc9xwpp', 'httpstcodfxhwn3yyx'], 'en']
# ['171', ['@drtedro', 'standard', 'definit', 'help', 'clinician', 'identifi', 'patient', 'easili', 'amp', 'provid', 'appropri', 'care', 'amp', 'crucial', 'advanc', 'recognit', 'amp', 'research', 'encourag', 'nation', 'author', 'polici', 'maker', 'amp', 'clinician', 'adopt', 'definition@drtedro'], 'en']
# ['172', ['@drtedro', 'patient', 'report', 'symptom', 'post', '#covid19', 'condit', 'much', 'longer', '2', 'month', 'common', 'symptom', 'includ', 'fatigu', 'short', 'breath', 'cognit', 'dysfunct', 'other', 'impact', 'everyday', 'functioning@drtedro'], 'en']
# ['173', ['@drtedro', 'definit', 'say', 'post', '#covid19', 'condit', 'usual', 'occur', '3', 'month', 'onset', 'covid19', 'symptom', 'last', 'least', '2', 'month', 'amp', 'cannot', 'explain', 'altern', 'diagnosis@drtedro', 'httpstcoyqu7lcxhpo'], 'en']
# ['174', ['@drtedro', 'yesterday', 'global', 'consult', 'patient', 'expert', 'publish', 'clinic', 'case', 'definit', 'post', '#covid19', 'condition@drtedro', 'httpstcoy9hgvp2r9h'], 'en']
# ['175', ['@drtedro', 'although', '#vaccinequ', 'help', 'end', 'pandem', 'effect', 'continu', 'felt', 'mani', 'year', 'especi', 'peopl', 'infect', 'continu', 'suffer', 'effect', 'post', '#covid19', 'condit', 'also', 'known', 'long', 'covid@drtedro'], 'en']
# ['176', ['@drtedro', 'strategi', 'achiev', 'global', '#covid19', 'vaccin', 'mid2022', 'httpstcobtneywdiuh', '#vaccinequ'], 'en']
# ['177', ['call', 'global', 'region', 'multilater', 'develop', 'bank', 'support', 'countri', 'rapid', 'access', 'capit', 'need', 'fund', '#covid19', 'vaccin', 'deliveri', 'programmes@drtedro', '#vaccinequ'], 'en']
# ['178', ['call', 'countri', 'ensur', 'capac', 'place', 'use', '#covid19', 'vaccin', 'dose', 'rapid', 'effici', 'possible@drtedro', '#vaccinequ'], 'en']
# ['179', ['call', 'civil', 'societi', 'communiti', 'organ', 'privat', 'sector', 'continu', 'advoc', 'local', 'nation', 'global', 'equit', 'access', 'vaccin', 'also', 'test', 'treatments@drtedro', '#covid19', '#actogeth'], 'en']
# ['180', ['call', 'vaccin', 'manufactur', 'priorit', 'amp', 'fulfil', 'contract', '#covax', 'amp', 'avat', 'matter', 'urgenc', 'transpar', 'go', 'share', 'knowhow', 'amp', 'nonexclus', 'licens', 'enabl', 'region', 'increas', 'manufactur', 'capacity@drtedro', '#vaccinequ'], 'en']
# ['181', ['call', '#covid19', 'vaccineproduc', 'countri', 'allow', 'free', 'crossbord', 'flow', 'finish', 'vaccin', 'raw', 'materi', 'enabl', 'share', 'knowhow', 'technolog', 'licenses@drtedro', '#vaccinequ'], 'en']
# ['182', ['call', 'countri', 'high', '#covid19', 'vaccin', 'coverag', 'swap', 'deliveri', 'schedul', '#covax', 'avat', 'fulfil', 'doseshar', 'pledg', 'immediately@drtedro', '#vaccinequ'], 'en']
# ['183', ['call', 'countri', 'updat', 'nation', '#covid19', 'vaccin', 'target', 'plan', 'guid', 'manufactur', 'invest', 'vaccin', 'distribution@drtedro', '#vaccinequ'], 'en']
# ['184', ['@drtedro', '@antonioguterr', 'today', 'im', 'delight', 'join', '@un', 'secretarygener', '@antonioguterr', 'like', 'us', 'long', 'call', 'global', '#vaccinequ', 'said', 'plan', 'succeed', 'everyon', 'cooperation@drtedro', 'httpstcoxsqgvd4kk3'], 'en']
# ['185', ['@drtedro', '@antonioguterr', '#vaccinequ', 'acceler', 'end', '#covid19', 'pandem', 'achiev', 'whos', 'vaccin', 'equiti', 'target', 'substanti', 'increas', 'popul', 'immun', 'global', 'protect', 'health', 'system', 'enabl', 'economi', 'fulli', 'restart', 'reduc', 'risk', 'new', 'variant', 'emerging@drtedro'], 'en']
# ['186', ['@drtedro', '@antonioguterr', 'must', 'rememb', '#covid19', 'vaccin', 'power', 'tool', 'one', 'countri', 'must', 'continu', 'comprehens', 'riskbas', 'approach', 'public', 'health', 'social', 'measur', 'combin', 'equit', 'vaccination@drtedro'], 'en']
# ['187', ['@drtedro', '@antonioguterr', '#', '@drtedro', '#vaccinequ'], 'en']
# ['188', ['@drtedro', '@antonioguterr', 'achiev', 'target', 'countri', 'compani', 'control', '#covid19', 'vaccin', 'suppli', 'put', 'contract', '#covax', 'african', 'vaccin', 'acquisit', 'trust', 'avat', 'first', 'deliveri', 'donat', 'doses@drtedro', '#vaccinequ'], 'en']
# ['189', ['@drtedro', '@antonioguterr', 'contract', 'place', 'remain', '5', 'billion', 'dose', 'critic', 'dose', 'go', 'need', 'prioriti', 'given', 'older', 'peopl', 'health', 'worker', 'atrisk', 'groups@drtedro', '#covid19', '#vaccinequ', 'httpstcobygl2ccvlk'], 'en']
# ['190', ['@drtedro', '@antonioguterr', 'end', 'septemb', 'almost', '65', 'billion', 'dose', 'alreadi', 'administ', 'global', '#covid19', 'vaccin', 'product', 'near', '15', 'billion', 'dose', 'per', 'month', 'enough', 'suppli', 'achiev', 'target', 'provid', 'distribut', 'equitably@drtedro', '#vaccinequ'], 'en']
# ['191', ['@drtedro', '@antonioguterr', 'achiev', 'target', 'requir', 'least', '11', 'billion', 'vaccin', 'dose', 'suppli', 'problem', 'alloc', 'problem@drtedro', '#vaccinequ', 'httpstcohi0tz50h79'], 'en']
# ['192', ['@drtedro', '@antonioguterr', 'today', 'launch', 'strategi', 'achiev', 'global', '#covid19', 'vaccin', 'mid2022', 'outlin', 'road', 'must', 'take', 'togeth', 'achiev', 'target', 'vaccin', '40', 'popul', 'everi', 'countri', 'end', '2021', '70', 'middl', 'next', 'year@drtedro'], 'en']
# ['193', ['@drtedro', '@antonioguterr', 'know', 'earlier', 'year', 'set', 'target', 'countri', 'vaccin', '10', 'popul', 'end', 'septemb', '56', 'countri', 'didnt', 'make', 'fault', 'own@drtedro', '#covid19', '#vaccinequ', 'httpstcofmtp3tylbk'], 'en']
# ['194', ['@drtedro', '@antonioguterr', 'high', 'uppermiddl', 'incom', 'countri', 'use', '75', '#covid19', 'vaccin', 'produc', 'far', 'lowincom', 'countri', 'receiv', 'less', 'half', 'one', 'percent', 'world', 'vaccin', 'africa', 'less', '5', 'peopl', 'fulli', 'vaccinated@drtedro', '#vaccinequ'], 'en']
# ['195', ['@drtedro', '@antonioguterr', '64', 'billion', 'vaccin', 'dose', 'administ', 'global', 'almost', 'onethird', 'world', 'popul', 'fulli', 'vaccin', '#covid19', 'number', 'mask', 'horrifi', 'inequity@drtedro'], 'en']
# ['196', ['@drtedro', '@antonioguterr', 'develop', 'approv', '#covid19', 'vaccin', 'record', 'time', 'took', 'us', 'summit', 'scientif', 'achiev', 'stand', 'precipic', 'failur', 'dont', 'make', 'benefit', 'scienc', 'avail', 'peopl', 'countri', 'right', 'now@drtedro', '#vaccinequ'], 'en']
# ['197', ['@drtedro', '@antonioguterr', 'press', 'confer', 'almost', 'exact', 'one', 'year', 'ago', 'said', 'world', 'eager', 'anticip', 'result', 'trial', 'vaccin', '#covid19', 'said', 'must', 'use', 'effect', 'make', 'sure', 'avail', 'countri', 'equitably@drtedro'], 'en']
# ['198', ['live', 'media', 'brief', '#covid19', '@drtedro', 'secretarygener', '@antonioguterr', '#vaccinequ', 'httpstco3qn9jckr7o'], 'en']
# ['199', ['peopl', 'post', '#covid19', 'condit', 'experi', 'linger', 'symptom', 'month', 'recoveri', 'symptom', 'may', 'begin', 'right', 'sick', 'covid19', 'later', 'may', 'come', 'go', 'httpstcowoilcwsgjx', 'httpstcojrabql2efx'], 'en']
# ['200', ['clinic', 'case', 'definit', 'post', '#covid19', 'condit', 'also', 'call', 'long', 'covid', 'httpstcowoilcwsgjx', 'httpstcoz0olrhlwpc'], 'en']
# ['201', ['live', '@twitterspac', '#askwho', 'first', 'ever', '#malaria', 'vaccin', '@katelobrien', '@palonsomalaria', 'answer', 'question', 'httpstcogz6n7nqb6p'], 'en']
# ['202', ['want', 'learn', 'first', 'ever', '#malaria', 'vaccin', 'use', 'join', '@twitterspac', 'chat', '@katelobrien', '@palonsomalaria', 'today', '1100', 'cest', '#askwho', 'httpstcosuimisvfcv'], 'en']
# ['203', ['rt', '@drtedro', 'start', 'career', '#malaria', 'research', 'long', 'day', 'would', 'effect', 'vaccin'], 'en']
# ['205', ['rtss', '#malaria', 'vaccin', 'introduc', 'pilot', 'programm', 'two', 'year', 'ago', 'sinc', '23', 'million', 'dose', 'vaccin', 'administ', 'across', 'ghana', 'kenya', 'malawi', 'httpstcoxsk58ntiv1', '#vaccineswork', 'httpstcojfvn5esxp'], 'en']
# ['206', ['800k', 'children', 'far', 'receiv', 'rtss', '#malaria', 'vaccin', 'amp', 'benefit', 'addit', 'protect', 'malaria', 'vaccin', 'signific', 'reduc', 'malaria', 'amp', 'lifethreaten', 'sever', 'case', 'could', 'save', 'ten', 'thousand', 'young', 'live', 'year', '#vaccineswork', 'httpstcostqwqfgcti'], 'en']
# ['207', ['child', 'die', '#malaria', 'everi', 'two', 'minut', 'one', 'death', 'one', 'mani', 'today', 'recommend', 'rtss', 'groundbreak', 'malaria', 'vaccin', 'reduc', 'child', 'ill', 'amp', 'death', 'area', 'moder', 'high', 'malaria', 'transmiss', 'httpstcoxsk58ntiv1', '#vaccineswork', 'httpstcomsecltrhq'], 'en']
# ['208', ['@drtedro', '@mohgovgh', '@mohkenya', '@healthmalawi', '@pathtweet', '@gatesfound', '@gavi', '@globalfund', '@unitaid', 'still', 'long', 'road', 'travel', 'long', 'stride', 'road', '#malaria', 'vaccin', 'gift', 'valu', 'felt', 'africa', 'that', 'burden', 'malaria', 'greatest@drtedro', '#endmalaria'], 'en']
# ['209', ['@drtedro', '@mohgovgh', '@mohkenya', '@healthmalawi', '@pathtweet', '@gatesfound', '@gavi', '@globalfund', '@unitaid', '#malaria', 'us', 'millennia', 'dream', 'malaria', 'vaccin', 'longheld', 'unattain', 'dream', 'today', 'rtss', 'malaria', 'vaccin', '30', 'year', 'make', 'chang', 'cours', 'public', 'health', 'history@drtedro', '#endmalaria'], 'en']
# ['210', ['@drtedro', '@mohgovgh', '@mohkenya', '@healthmalawi', 'thank', 'glaxosmithklin', 'amp', 'mani', 'research', 'partner', 'creat', '#malria', 'amp', '@pathtweet', 'bring', 'discoveri', 'develop', 'support', '@gatesfound', 'thank', '@gavi', '@globalfund', 'amp', '@unitaid', 'fund', 'pilot', 'programm', 'amp', 'evaluations@drtedro'], 'en']
# ['211', ['@drtedro', '@mohgovgh', '@mohkenya', '@healthmalawi', 'thank', 'research', 'africa', 'generat', 'data', 'insight', 'inform', 'decis', 'vaccin', 'develop', 'africa', 'african', 'scientists@drtedro', '#endmalaria'], 'en']
# ['212', ['@drtedro', 'thank', 'children', 'famili', 'communiti', 'particip', 'histor', 'pilot', 'programm', 'thank', '@mohgovgh', '@mohkenya', '@healthmalawi', 'leadership', 'embark', 'pilot', 'programm', 'continu', 'despit', '#covid19@drtedro', '#endmalaria'], 'en']
# ['213', ['@drtedro', 'power', 'new', 'tool', 'like', '#covid19', 'vaccin', 'tool', 'vaccin', '#malaria', 'replac', 'reduc', 'need', 'measur', 'includ', 'bednet', 'seek', 'care', 'fever@drtedro', '#endmalaria'], 'en']
# ['214', ['@drtedro', 'broad', 'reach', 'children', 'incl', 'vulner', 'may', 'use', 'bednet', 'safe', 'signific', 'reduc', 'lifethreaten', 'sever', '#malaria', 'estim', 'high', 'costeffective@drtedro', '#endmalaira', 'httpstco4snq2shie'], 'en']
# ['215', ['@drtedro', 'weve', 'learn', '#malaria', 'vaccin', 'deliv', 'child', 'health', 'clinic', 'ministri', 'health', 'readili', 'reach', 'children', 'high', 'coverag', 'level', 'communiti', 'demand', 'vaccin', 'strong@drtedro', '#endmalaria'], 'en']
# ['216', ['@drtedro', 'said', 'consist', 'need', 'new', 'tool', 'get', '#malaria', 'control', 'back', 'track', 'two', 'year', 'ago', 'partner', 'began', 'pilot', 'programm', 'roll', 'vaccin', '@drtedro', '#endmalaria', 'httpstcow5tbsmrian'], 'en']
# ['217', ['@drtedro', 'global', 'progress', 'stall', 'unaccept', 'high', 'level', '200', 'million', 'case', '400', 'thousand', 'death', 'everi', 'year', 'twothird', 'death', 'children', 'five', 'africa@drtedro', '#endmalaria', 'httpstco5pgwhpf6dt'], 'en']
# ['218', ['@drtedro', 'made', 'incred', 'progress', 'fight', '#malaria', 'past', '2', 'decad', 'sinc', '2000', 'malaria', 'death', 'fallen', 'half', 'succeed', 'elimin', 'malaria', 'mani', 'part', 'world@drtedro', '#endmalaria'], 'en']
# ['219', ['@drtedro', 'longawait', '#malaria', 'vaccin', 'breakthrough', 'scienc', 'child', 'health', 'malaria', 'control', 'use', 'vaccin', 'addit', 'exist', 'tool', 'prevent', 'malaria', 'could', 'save', 'ten', 'thousand', 'young', 'live', 'year@drtedro', '#endmalaria', 'httpstcoy2z8pfe2xx'], 'en']
# ['220', ['@drtedro', '#', 'recommend', 'base', 'result', 'ongo', 'pilot', 'programm', 'amp', 'reach', '800k', 'children', 'sinc', '2019', '@drtedro', 'httpstcownnjvkbstp'], 'en']
# ['221', ['@drtedro', 'may', 'know', 'start', 'career', '#malaria', 'research', 'long', 'day', 'would', 'effect', 'vaccin', 'ancient', 'terribl', 'diseas', 'today', 'day', 'histor', 'day@drtedro', '#endmalaria', 'httpstcoiztfgcowhh'], 'en']
# ['222', ['live', 'media', 'brief', '@drtedro', '#malaria', 'vaccin', 'recommend', '#endmalaria', 'httpstcoc5ojrtrplk'], 'en']
# ['223', ['rt', '@whomalawi', 'octob', 'breast', 'cancer', 'awar', 'month', 'prevent', 'breast', 'cancer', 'dont', 'smoke', 'control', 'weight', 'l'], 'en']
# ['224', ['rt', '@whowpro', '#mening', 'danger', 'inflamm', 'membran', 'surround', 'brain', 'spinal', 'cord', 'predomin', 'caus', 'inf'], 'en']
# ['225', ['block', 'calendar', '@twitterspac', 'chat', '#mentalhealth', 'amp', 'young', 'peopl', 'saturday', '9', 'octob', '1200pm', 'cest', '#askwho', '#worldmentalhealthday', 'httpstcoqbpyqqwytq'], 'en']
# ['226', ['saturday', 'kick', '#worldmentalhealthday', '#askwho', '@twitterspac', 'chat', 'block', 'calendar', 'discuss', 'expert', 'special', 'guest', 'httpstcognflm31qsl'], 'en']
# ['227', ['rt', '@drtedro', 'merci', 'beaucoup', 'sister', 'kandia', 'camara', '#cotedivoir', 'foreign', 'minist', 'visit', '@who', 'product', 'disc'], 'en']
# ['228', ['provid', 'support', 'deliv', 'essenti', 'packag', 'highqual', 'matern', 'newborn', 'servic', 'technic', 'guidanc', 'support', 'countri', 'around', 'httpstcodhtf3jxqb0', 'httpstcoleipe4c3iq'], 'en']
# ['229', ['live', 'qampa', '#covid19', '@drmikeryan', 'dr', '@mvankerkhov', '#askwho', 'httpstcoanvyvthe9k'], 'en']
# ['230', ['emerg', 'use', 'list', 'process', 'done', 'technic', 'advisori', 'group', 'independ', 'expert', 'centr', 'determin', 'manufactur', 'product', 'eg', 'vaccin', 'qualityassur', 'safe', 'effect', 'httpstconpxpaqav2f'], 'en']
# ...
# ['2321', ['watch', 'next', 'panel', 'tackl', 'noncommunic', 'diseas', 'mental', 'health', 'crise', 'healthier', 'small', 'island', 'develop', 'state', 'visit', 'websit', 'httpstcowpuhzyccfm', '#beatncd'], 'en']
# ['2322', ['#ai', 'system', 'design', 'reflect', 'divers', 'socioeconom', 'amp', 'healthcar', 'set', 'healthcar', 'worker', 'given', 'proper', 'train', 'ensur', 'remain', 'full', 'control', 'healthcar', 'system', 'amp', 'medic', 'decis', 'detail', 'httpstcoxcnf3imbcr', 'httpstcodhjmgg5s7u'], 'en']
# ['2323', ['uneth', 'collect', 'amp', 'use', 'health', 'data', 'bias', 'encod', 'algorithm', 'risk', 'ai', 'patient', 'safeti', 'digit', 'surveil', 'risk', 'associ', 'use', '#ai', 'health', 'info', 'httpstcoxcnf3imbcr', 'httpstcoiitxdsiaw'], 'en']
# ['2324', ['#ai', 'use', 'improv', 'patient', 'amp', 'clinic', 'care', 'diagnosi', 'amp', 'screen', 'diseas', 'health', 'research', 'pandem', 'prepared', 'amp', 'respons', 'amp', 'whos', 'report', 'explain', 'address', 'ethic', 'challeng', 'fulli', 'unlock', 'potenti', 'ai', 'httpstcofc7sx51yzi', 'httpstcog23sxkqdyp'], 'en']
# ['2325', ['artifici', 'intellig', '#ai', 'hold', 'enorm', 'potenti', 'improv', 'health', 'million', 'peopl', 'around', 'ethic', 'amp', 'human', 'right', 'put', 'heart', 'design', 'deploy', 'amp', 'use', 'whos', 'first', 'global', 'report', 'ai', 'amp', 'healthhttpstcofc7sx51yzi', 'httpstco1jp0aspdy3'], 'en']
# ['2326', ['@drtedro', 'full', 'remark', '@drtedro', 'httpstcooynscury47'], 'en']
# ['2327', ['global', 'health', 'secur', 'without', 'local', 'health', 'secur', '#pandemictreati', 'would', 'foster', 'improv', 'share', 'trust', 'account', 'help', 'strengthen', 'nation', 'region', 'global', 'capac', 'global', 'health', 'security@drtedro'], 'en']
# ['2328', ['5we', 'must', 'learn', 'lesson', '#covid19', 'pandem', 'teach', 'us', 'must', 'everyth', 'prepar', 'prevent', 'detect', 'respond', 'rapid', 'futur', 'epidem', 'pandem', 'base', 'upon', 'foundat', 'univers', 'health', 'coverag', 'amp', 'strong', '#primaryhealthcare@drtedro'], 'en']
# ['2329', ['4who', 'continu', 'support', 'effort', 'progress', 'toward', 'univers', 'health', 'coverag', 'strengthen', '#primaryhealthcar', 'workforc', 'data', 'platform', 'also', 'continu', 'exist', 'work', 'expand', 'pool', 'procur', 'regulatori', 'schemes@drtedro'], 'en']
# ['2330', ['3we', 'work', 'scaleup', 'integr', 'servic', 'prevent', '#beatncd', 'especi', 'obes', 'diabet', 'hypertens', 'tobacco', 'use@drtedro'], 'en']
# ['2331', ['2who', 'help', 'sid', 'mobil', 'fund', '#climatechang', 'adapt', 'resili', 'health', 'system', 'food', 'secur', 'amp', 'emerg', 'prepared', 'amp', 'respons', 'offer', 'support', 'sid', 'better', 'util', 'financ', 'platform', 'green', 'climat', 'fund@drtedro'], 'en']
# ['2332', ['let', 'suggest', 'key', 'area', 'offer', 'support', '1we', 'must', 'work', 'togeth', '#vaccinequ', 'mean', 'share', 'amp', 'invest', 'local', 'amp', 'region', 'product', 'also', 'need', 'share', 'knowhow', 'technolog', 'licens', 'amp', 'waiv', 'ip', 'rights@drtedro'], 'en']
# ['2333', ['also', 'want', 'ensur', 'support', 'fitforpurpos', 'sid', 'summit', 'important@drtedro', 'httpstcojxabajh3aw'], 'en']
# ['2334', ['sid', 'summit', 'health', 'offer', 'opportun', 'galvan', 'target', 'support', 'healthi', 'resili', 'futur', 'small', 'island', 'develop', 'state', 'mean', 'strengthen', 'financ', 'workforc', 'capac', 'data', 'evid', 'partnership', 'across', 'sids@drtedro'], 'en']
# ['2335', ['2019', 'privileg', 'visit', 'sever', 'island', 'pacif', 'includ', 'fiji', 'tahiti', 'tuvalu', 'tonga', 'bahama', 'see', 'impact', '#climatechang', 'countries@drtedro', 'httpstcowote7g4zmi'], 'en']
# ['2336', ['even', '#covid19', 'pandem', 'subsid', 'know', 'mani', 'still', 'left', 'face', 'mani', 'health', 'challeng', 'struck@drtedro'], 'en']
# ['2337', ['also', 'need', 'great', 'expand', 'invest', 'local', 'product', 'world', 'depend', 'upon', 'countri', 'produc', 'vaccin', 'essenti', 'health', 'products@drtedro', '#vaccinequ'], 'en']
# ['2338', ['past', 'week', 'seen', 'encourag', 'sign', 'recent', 'commit', 'vaccin', 'produc', 'countri', 'share', 'hundr', 'million', 'dose', 'that', 'still', 'near', 'enough', 'need', 'need', 'come', 'faster@drtedro', '#vaccinequ'], 'en']
# ['2339', ['know', 'nowher', 'near', 'enough', 'need', 'amp', 'work', 'hard', 'find', 'way', 'increas', 'product', 'amp', '#vaccinequ', 'face', 'problem', 'around', 'inequ', 'amp', 'nation', 'deepen', 'divid', 'high', 'amp', 'lowerincom', 'nations@drtedro'], 'en']
# ['2340', ['major', 'hurdl', 'recoveri', 'remain', 'equit', 'access', '#covid19', 'vaccin', '#covax', 'far', 'abl', 'deliv', 'two', 'million', 'vaccin', '31', 'small', 'island', 'develop', 'state', 'well', 'essenti', 'health', 'products@drtedro', '#vaccinequ', 'httpstcoxbtw38jaco'], 'en']
# ['2341', ['mani', 'succeed', 'prevent', 'widespread', 'transmiss', '#covid19', 'communiti', 'know', 'pandem', 'hit', 'hard', 'way', 'declin', 'revenu', 'tourism', 'affect', 'economi', 'significantly@drtedro'], 'en']
# ['2342', ['despit', 'serious', 'risk', 'sid', 'proven', 'true', 'health', 'leader', 'safeguard', 'health', 'wellb', 'communiti', 'time', 'catalys', 'polit', 'momentum', 'global', 'health', 'goals@drtedro', 'httpstcoknejfavvji'], 'en']
# ['2343', ['#covid19', 'present', 'dire', 'econom', 'health', 'crisi', 'sid', 'health', 'risk', '#climatechang', 'noncommunic', 'diseas', 'malnutrit', 'put', 'communiti', 'risk@drtedro'], 'en']
# ['2344', ['would', 'like', 'warm', 'welcom', 'sid', 'summit', 'health', 'first', 'ever', 'gather', 'leader', 'focus', 'exclus', 'health', 'small', 'island', 'develop', 'state', 'today', 'mani', 'health', 'threat', 'nation', 'face@drtedro', 'httpstco54d71e7pow'], 'en']
# ['2345', ['open', 'small', 'island', 'develop', 'state', 'summit', 'health', '@drtedro', 'httpstcostcyrutron'], 'en']
# ['2346', ['summer', 'holiday', 'chanc', 'amp', 'kid', 'stay', 'healthi', '#beactiv', 'togeth', 'let', 'take', '20minut', 'break', 'amp', 'someth', 'kid', 'choos', 'get', 'creativ', 'play', 'game', 'danc', 'song', 'pick', '#selfcar', 'month', 'httpstcobjqm0fdiec'], 'en']
# ['2347', ['rt', '@who', 'live', 'qampa', '#covid19', 'variant', 'vaccin', '@doctorsoumya', '#askwho', 'httpstcorffqvz1kmp'], 'en']
# ['2348', ['rt', '@opsargentin', 'florenci', 'recurs', 'digital', 'oms', '@who', 'pued', 'ayudart', 'consej', 'til', 'plan', 'cmo', 'dej', 'tabac', 'https'], 'es']
# ['2349', ['exist', 'vaccin', 'protect', '#covid19', 'variant', 'concern', 'httpstcovqhlcib7pq'], 'en']
# ['2350', ['live', '@drtedro', '@whskampala', 'httpstcosfy1npsla3'], 'en']
# ['2351', ['rt', '@drtedro', 'glad', 'see', 'vital', '#covid19', 'vaccin', 'way', 'peopl', 'need', 'hondura', 'via', '#covax', 'call', 'govern'], 'en']
# ['2352', ['rt', '@drtedro', 'pride', 'amp', 'humil', 'accept', 'award', '@genevadiplomaci', 'behalf', '@who', 'colleagu', '#p'], 'en']
# ['2353', ['live', '@drtedro', 'geneva', 'school', 'diplomaci', 'graduat', 'amp', 'award', 'ceremoni', '#proudtobewho', 'httpstcoxzgtenc5fc'], 'en']
# ['2354', ['recommend', 'healthi', 'adult', '30', 'minsday', 'physic', 'activ', 'children', 'physic', 'activ', '1', 'hourday', '#beactiv', '#selfcar', 'month', 'httpstcoyudedmwfnm'], 'en']
# ['2355', ['#covid19', 'delta', 'plus', 'variant', 'httpstcoogvchiafep'], 'en']
# ['2356', ['know', '#covid19', 'delta', 'variant', 'httpstco0cxwxr3rec'], 'en']
# ['2357', ['make', 'time', 'day', 'also', 'good', '#mentalhealth', 'consid', 'meditatingand', 'deep', 'breath', 'exercis', 'along', 'relax', 'techniqu', 'help', 'reduc', 'stress', '#selfcar', 'month', 'httpstcoxq665ikzdu'], 'en']
# ['2358', ['even', 'get', 'vaccin', '#covid19', 'keep', 'take', 'precaut', 'protect', 'famili', 'friend', 'httpstcoz8gwj9bjb'], 'en']
# ['2359', ['rt', '@drtedro', 'there', 'lot', 'concern', '#covid19', 'delta', 'variant', 'transmiss', 'one', 'identifi', 'far', 'must', 'use', 'tailor'], 'en']
# ['2360', ['rt', '@drtedro', 'horrif', 'news', 'friend', '@drchristou', '@who', 'colleagu', 'amp', 'devast', 'brutal', 'murder', '3', '@msf', 'staff', 'member'], 'en']
# ['2361', ['join', 'condemn', 'murder', 'three', '@msf', 'colleagu', '#tigray', 'ethiopia', 'amp', 'express', 'deepest', 'sympathi', 'famili', 'amp', 'friend', 'msf', 'come', 'day', 'shock', 'attack', 'civilian', 'market', 'near', 'mekell', 'attack', 'appal', 'amp', 'must', 'stop', 'httpstcogkj2rfyvz7'], 'en']
# ['2362', ['@drtedro', 'current', 'provid', 'lifesav', 'trauma', 'surgic', 'suppli', 'hospit', 'treat', 'survivor', 'abl', 'reach', 'care', 'attack', 'civilian', 'anywher', 'complet', 'unaccept', 'deni', 'access', 'immedi', 'care@drtedro', 'httpstcopihljmpexh'], 'en']
# ['2363', ['@drtedro', 'wednesday', 'market', 'outsid', 'citi', 'mekell', '#tigray', 'region', 'bomb', 'kill', 'wound', 'civilian', 'ambul', 'block', 'day', 'attend', 'scene', 'evacu', 'wound', 'medic', 'care@drtedro'], 'en']
# ['2364', ['@drtedro', 'say', 'whos', 'emerg', 'medic', 'team', 'initi', 'im', 'delight', 'welcom', 'ambassador', 'toni', 'frisch', 'chair', 'emt', 'strateg', 'advisori', 'group', 'ambassador', 'frisch', 'play', 'critic', 'role', 'guid', 'emt', 'initi', 'mani', 'years@drtedro', 'httpstcogxappjwn1h'], 'en']
# ['2365', ['@drtedro', 'repres', 'major', 'step', 'forward', 'ensur', 'emerg', 'medic', 'team', 'meet', 'share', 'standard', 'qualiti', 'care', 'whether', 'deploy', 'nation', 'internationally@drtedro', 'httpstcou28f3s7i49'], 'en']
# ['2366', ['@drtedro', 'last', 'week', 'partner', 'publish', 'new', 'standard', 'deploy', 'emerg', 'medic', 'team', 'rang', 'situat', 'natur', 'disast', 'epidem', 'conflict', 'situations@drtedro'], 'en']
# ['2367', ['@drtedro', 'greec', 'team', 'norway', 'germani', 'deploy', 'follow', 'fire', 'refuge', 'camp', 'island', 'lesvo', 'support', '#covid19', 'respons', 'togeth', 'essenti', 'health', 'services@drtedro'], 'en']
# ['2368', ['@drtedro', 'recent', 'deploy', 'emerg', 'medic', 'team', 'djibouti', 'papua', 'new', 'guinea', 'fiji', 'costa', 'rica@drtedro', 'httpstcoisxdiekvmq'], 'en']
# ['2369', ['@drtedro', 'sinc', 'begin', '#covid19', 'pandem', 'facilit', 'deploy', '108', 'intern', 'emt', 'amp', 'expert', 'worldwid', 'team', 'provid', 'special', 'care', 'patient', 'addit', 'bed', 'capac', 'amp', 'advic', 'local', 'health', 'provid', 'case', 'management@drtedro'], 'en']
# ['2370', ['@drtedro', '87', 'countri', 'either', 'team', 'process', 'certifi', 'develop', 'system', 'qualityassur', 'nation', 'teams@drtedro', 'httpstcowwdwh23cuf'], 'en']
# ['2371', ['@drtedro', 'global', 'certifi', 'team', '20', 'countri', 'gone', 'rigor', 'process', 'qualiti', 'assur', 'ensur', 'meet', 'intern', 'agre', 'standards@drtedro'], 'en']
# ['2372', ['@drtedro', 'emerg', 'strike', 'emt', 'mobil', 'support', 'nation', 'respons', 'treat', 'patient', 'provid', 'train', 'supervis', 'strengthen', 'coordin', 'ensur', 'standard', 'met', 'qualiti', 'care@drtedro', 'httpstcoz71k0txszo'], 'en']
# ['2373', ['@drtedro', 'emt', 'made', 'dedic', 'profession', 'permiss', 'take', 'time', 'away', 'regular', 'job', 'respond', 'emerg', 'either', 'nation', 'internationally@drtedro', 'httpstcoskcl95hbvu'], 'en']
# ['2374', ['@drtedro', 'emerg', 'medic', 'team', 'emt', 'group', 'health', 'profession', 'includ', 'doctor', 'nurs', 'paramed', 'support', 'worker', 'logistician', 'provid', 'care', 'patient', 'affect', 'emergency@drtedro', 'httpstcogskrv0iklj'], 'en']
# ['2375', ['@drtedro', 'one', 'import', 'way', 'coordin', 'respons', '#covid19', 'emerg', 'global', 'network', 'emerg', 'medic', 'teams@drtedro', 'httpstco5cfxl3qzpo'], 'en']
# ['2376', ['@drtedro', 'past', '18', 'month', 'staff', 'done', 'amaz', 'job', 'support', 'countri', 'respond', '#covid19', 'cant', 'everywher', 'cant', 'everything@drtedro'], 'en']
# ['2377', ['@drtedro', 'say', 'least', 'year', 'vaccin', 'must', 'distribut', 'equit', 'protect', 'health', 'worker', 'vulnerable@drtedro', '#covid19', '#vaccinequ', 'httpstcoxsovedfnri'], 'en']
# ['2378', ['@drtedro', 'make', 'even', 'urgent', 'use', 'tool', 'dispos', 'prevent', '#covid19', 'transmiss', 'tailor', 'consist', 'use', 'public', 'health', 'social', 'measur', 'combin', '#vaccinequity@drtedro', 'httpstcoigfsehshnn'], 'en']
# ['2379', ['@drtedro', 'new', 'variant', 'expect', 'continu', 'report', 'that', 'virus', 'evolv', 'prevent', 'emerg', 'variant', 'prevent', '#covid19', 'transmiss', 'quit', 'simpl', 'transmiss', 'variant', 'less', 'transmiss', 'less', 'variants@drtedro'], 'en']
# ['2380', ['@drtedro', 'countri', 'eas', 'public', 'health', 'social', 'measur', 'start', 'see', 'increas', '#covid19', 'transmiss', 'around', 'world', 'case', 'mean', 'hospit', 'stretch', 'health', 'worker', 'health', 'system', 'increas', 'risk', 'death@drtedro'], 'en']
# ['2381', ['@drtedro', 'delta', 'variant', 'transmiss', '#covid19', 'variant', 'identifi', 'far', 'identifi', 'least', '85', 'countri', 'spread', 'rapid', 'among', 'unvaccin', 'populations@drtedro', 'httpstcohqfrixfvoi'], 'en']
# ['2382', ['@drtedro', 'know', 'global', 'current', 'lot', 'concern', '#covid19', 'delta', 'variant', 'concern', 'too@drtedro', 'httpstcohqfrixfvoi'], 'en']
# ['2383', ['media', 'brief', '#covid19', '@drtedro', 'httpstcoyimdhdifq0'], 'en']
# ['2384', ['rt', '@who', 'even', 'get', 'vaccin', '#covid19', 'protect', 'famili', 'friend', 'httpstcobnogx254mb'], 'en']
# ['2385', ['#selfcar', 'technolog', 'help', 'peopl', 'look', 'sexual', 'amp', 'reproduct', 'health', 'selfinject', 'contracept', 'hiv', 'amphepat', 'c', 'selftest', 'selfsampl', 'hpv', 'selftest', 'ovul', 'predictor', 'kit', 'fertil', 'manag', 'httpstcodddfj4ppem'], 'en']
# ['2386', ['get', 'vaccin', 'even', '#covid19'], 'en']
# ['2387', ['new', '#selfcar', 'recommend', 'includ', 'provis', 'selftest', 'prescript', 'pharmaci', 'access', 'emerg', 'contracept', 'selfmanag', 'iron', 'amp', 'folic', 'acid', 'supplement', 'selfmonitor', 'blood', 'glucos', 'amp', 'pressur', 'httpstcodddfj4ppem', 'httpstco6sjrf6yubd'], 'en']
# ['2388', ['#selfcar', 'intervent', 'complementari', '#primaryhealthcar', 'substitut', 'selfcar', 'choic', 'prompt', 'fear', 'lack', 'altern', 'increas', 'vulner', 'put', 'peopl', 'wellb', 'risk', 'httpstcodddfj4ppem', 'httpstcot810wf0yjj'], 'en']
# ['2389', ['#selfcar', 'abil', 'individu', 'famili', 'communiti', 'promot', 'health', 'prevent', 'diseas', 'maintain', 'health', 'cope', 'ill', 'disabl', 'without', 'support', 'health', 'worker', 'httpstcodddfj4ppem', 'httpstco5ipndmfnl7'], 'en']
# ['2390', ['celebr', '#selfcar', 'month', 'releas', 'new', 'guidelin', 'selfcar', 'intervent', 'health', 'new', 'recogn', 'peopl', 'activ', 'take', 'decis', 'health', 'health', 'one', 'httpstcoxzditnf4ni'], 'en']
# ['2391', ['even', 'get', 'vaccin', '#covid19', 'protect', 'famili', 'friend', 'httpstcobnogx254mb'], 'en']
# ['2392', ['live', 'qampa', '#covid19', 'variant', 'vaccin', '@doctorsoumya', '#askwho', 'httpstcorffqvz1kmp'], 'en']
# ['2393', ['take', 'time', 'day', 'thing', 'enjoy', 'stay', 'connect', 'keep', 'touch', 'peopl', 'care', 'think', 'other', 'reach', 'trust', 'person', 'health', 'worker', 'need', 'help', 'httpstco0u9jroshdx', 'httpstcoyzpiyhmvgi'], 'en']
# ['2394', ['maintain', 'healthi', 'lifestyl', 'vital', 'mean', 'eat', 'healthili', 'physic', 'activ', 'avoid', 'alcohol', 'tobacco', 'get', 'enough', 'sleep', 'httpstco0u9jrojscx', '#selfcar', 'month', 'httpstcocrf6gagsqw'], 'en']
# ['2395', ['today', 'day', '1', '#selfcar', 'month', 'throughout', 'month', 'well', 'share', 'tip', 'help', 'protect', 'health', '#covid19', 'pandem', 'beyond', 'httpstco0u9jrojscx'], 'en']
# ['2396', ['rt', '@drtedro', 'pleas', 'spoken', 'majesti', 'queen', 'mathild', '#belgium', 'upcom', 'impact', 'violenc', 'childr'], 'en']
# ['2397', ['rt', '@drtedro', '#covid19', 'situat', 'africa', 'worrisom', 'number', 'case', 'amp', 'death', 'almost', '40', 'higher', 'week'], 'en']
# ['2398', ['right', 'health', 'mean', 'right', 'control', 'one', 'health', 'bodi', 'includ', 'sexual', 'reproduct', 'health', 'right', 'women', 'girl', 'without', 'interfer', 'httpstco0xs5xwkotg', '#healthforal', '#standup4humanright', 'httpstcoqfh5pq8s2d'], 'en']
